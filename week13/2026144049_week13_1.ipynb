# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import xml.etree.ElementTree as et
file_path = '/content/drive/MyDrive/Colab Notebooks/menu.xml'
root = tree.getroot()

print(root.tag)
# Out:
# menu

# %%
for child in root:
    print('tag:', child.tag, 'attributes:', child.attrib)
    for grandchild in child:
        print('\ttag:', grandchild.tag, 'attributes:', grandchild.attrib)
# Out:
# tag: breakfast attributes: {'hours': '7-11'}
# 	tag: item attributes: {'price': '$6.00'}
# 	tag: item attributes: {'price': '$4.00'}
# tag: lunch attributes: {'hours': '11-3'}
# 	tag: item attributes: {'price': '$5.00'}
# tag: dinner attributes: {'hours': '3-10'}
# 	tag: item attributes: {'price': '8.00'}

# %%
len(root)
len(root[0])
# Out:
# 2

# %%
print(root[0])
print(root[0].get("hours"))
print(root[0].keys())
print(root[0].items())
# Out:
# <Element 'breakfast' at 0x7c413e2336f0>
# 7-11
# ['hours']
# [('hours', '7-11')]

# %%
lunch = root.find("lunch")
print(lunch)
print(lunch.get("hours"))
print(lunch.keys())
print(lunch.items())
# Out:
# <Element 'lunch' at 0x7c413e231760>
# 11-3
# ['hours']
# [('hours', '11-3')]

# %%
print(root[0].findall('item'))
# Out:
# [<Element 'item' at 0x7c413e230680>, <Element 'item' at 0x7c413e233290>]

# %%
for item in root[0].findall('item'):
    print(item.get('price'))
    print(item.text)
# Out:
# $6.00
# breakfast burritos
# $4.00
# pancakes

# %%
{
    "이름": "홍길동",
    "나이": 25,
    "성별": "여",
    "주소": "서울특별시 양천구 목동",
    "특기": ["농구", "도술"],
    "가족관계": {"#": 2, "아버지": "홍판서", "어머니": "춘섬"},
    "회사": "경기 수원시 팔달구 우만동"
}
# Out:
# {'이름': '홍길동',
#  '나이': 25,
#  '성별': '여',
#  '주소': '서울특별시 양천구 목동',
#  '특기': ['농구', '도술'],
#  '가족관계': {'#': 2, '아버지': '홍판서', '어머니': '춘섬'},
#  '회사': '경기 수원시 팔달구 우만동'}

# %%
data_dict = {
    "_index": "bank",
    "_type": "account",
    "_id": "1",
    "_version": 1,
    "found": True,
    "_source": {
        "account_number": 1,
        "balance": 39225,
        "firstname": "Amber",
        "lastname": "Duke",
        "age": 32,
        "gender": "M",
        "address": "880 Holmes Lane",
        "employer": "Pyrami",
        "email": "amberduke@pyrami.com",
        "city": "Brogan",
        "state": "IL"
    }
}
print(data_dict)
# Out:
# {'_index': 'bank', '_type': 'account', '_id': '1', '_version': 1, 'found': True, '_source': {'account_number': 1, 'balance': 39225, 'firstname': 'Amber', 'lastname': 'Duke', 'age': 32, 'gender': 'M', 'address': '880 Holmes Lane', 'employer': 'Pyrami', 'email': 'amberduke@pyrami.com', 'city': 'Brogan', 'state': 'IL'}}

# %%
import json

# %%
j1 = {"name": "홍길동", "birth": "0525", "age": 30}
print(j1)
print(json.dumps(j1))
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}
# {"name": "\ud64d\uae38\ub3d9", "birth": "0525", "age": 30}

# %%
print(json.dumps(j1, indent=2))
# Out:
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0525",
#   "age": 30
# }

# %%
print(json.dumps([1, 2, 3]))
print(json.dumps((4, 5, 6)))
# Out:
# [1, 2, 3]
# [4, 5, 6]

# %%
j1 = {"name": "홍길동", "birth": "0525", "age": 30}
d1 = json.dumps(j1)
print(json.loads(d1))
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
{
    "name": "홍길동",
    "birth": "0525",
    "age": 30
}
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
with open('./myinfo.json') as f:
    data = json.load(f)

print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'name': '홍길동', 'birth': '0525', 'age': 30}
