# %%
#2026144049 김동현 3주차 숙제1(Tuples)

genres_tuple = ("pop", "rock", "soul", "hard rock", "soft rock", \
                "R&B", "progressive rock", "disco")
genres_tuple
# Out:
# ('pop',
#  'rock',
#  'soul',
#  'hard rock',
#  'soft rock',
#  'R&B',
#  'progressive rock',
#  'disco')

# %%
#Find the length of the tuple, genres_tuple:
len(genres_tuple)
# Out:
# 8

# %%
#Access the element, with respect to index 3:
genres_tuple[3]
# Out:
# 'hard rock'

# %%
genres_tuple[3:6]
# Out:
# ('hard rock', 'soft rock', 'R&B')

# %%
genres_tuple[0:2]
# Out:
# ('pop', 'rock')

# %%
genres_tuple.index("disco")
# Out:
# 7

# %%
C_tuple=(-5, 1, -3)
list = sorted(C_tuple)
list
# Out:
# [-5, -3, 1]
