# %% [markdown]
# <a href="https://colab.research.google.com/github/donghyunKim71/python_programming/blob/main/2026144049-%EA%B9%80%EB%8F%99%ED%98%84-week2-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2026144049 김동현 2주차 숙제1
#Exercise 1 (Types) : Your First Program
print("Hello, world!")
# Out:
# Hello, world!
# 17
